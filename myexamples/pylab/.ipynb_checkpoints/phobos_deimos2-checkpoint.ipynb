# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import autoreload
# %load_ext autoreload
# %autoreload 2
from orbsubs import *   
# subroutines for plotting in orbsubs_ur

plt.rcParams.update({'font.size': 16})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
simdir = "../phobos_deimos2/" # where simulation output files are to be found
numberpm=1  # number of point masses in simulation

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.10;
parmfile='t4'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,100,0)  #  savefile, then tmin,tmax
##### figure for paper!!!!!
# Out:
# ../phobos_deimos2/t4_ext.txt
# ../phobos_deimos2/t4_pm0.txt
# kk= 1
# orbital period 33.71206739404667

# %%
numberpm=2  #  Deimos,   J2,C22,  drifting phobosX100, high gamma
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d10'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,2e4/70,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# figure for paper!
# Out:
# ../phobos_deimos2/d10_ext.txt
# ../phobos_deimos2/d10_pm0.txt
# ../phobos_deimos2/d10_pm1.txt
# kk= 1
# orbital period 70.3599468749234

# %%
simdir = "../phobos_wobble/" # where simulation output files are to be found
numberpm=1  # number of point masses in simulation
Rmars = 36.0; omega_Mars = 0.0;
parmfile='q4'  # parameter file for simulation
fileroot = simdir + parmfile
plt.rcParams.update({'font.size': 16})
plt_cols_Q(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,0,0)  #  savefile, then tmin,tmax

# figure for paper shown long lived NPA
# Out:
# ../phobos_wobble/q4_ext.txt
# ../phobos_wobble/q4_pm0.txt
# kk= 4
# orbital period 19.868628438320417

# %%
# nothing below here used in paper

# %%
numberpm=2  #  Deimos,   J2,C22,  drifting phobosX100, high gamma
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d11'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,1.5e4,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# figure for paper!
# Out:
# ../phobos_deimos2/d11_ext.txt
# ../phobos_deimos2/d11_pm0.txt
# ../phobos_deimos2/d11_pm1.txt
# kk= 1

# %%
# this is the Mars figure 2:1 resonance crossing of Phobos
numberpm=1  # number of point masses in simulation
Rmars = 301.0; omega_Mars = 0.10;
parmfile='t5'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_M(fileroot,numberpm,parmfile + '.png',Rmars,2*omega_Mars,100,1e5)  #  savefile, then tmin,tmax
##### check for paper
# Out:
# ../phobos_deimos2/t5_ext.txt
# ../phobos_deimos2/t5_pm0.txt
# kk= 1

# %%
# this is the mean motion 2:1 resonance crossing of Phobos/Deimos, Deimos resolved
numberpm=2  # number of point masses in simulation
Rmars = 547.0; omega_Mars = 0.11; afac = 2**(2/3)
parmfile='d1'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,1e3,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):

# this is not the 2:1 mmr this is the 2:1 with Mars, acting only on Phobos
# Out:
# ../phobos_deimos2/d1_ext.txt
# ../phobos_deimos2/d1_pm0.txt
# ../phobos_deimos2/d1_pm1.txt
# kk= 1

# %%
numberpm=2  #  Deimos no J2,C22,  drifting phobos, more massive phobos 100
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d5'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,0e3,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# Out:
# ../phobos_deimos2/d5_ext.txt
# ../phobos_deimos2/d5_pm0.txt
# ../phobos_deimos2/d5_pm1.txt
# kk= 1

# %%
numberpm=1  #  Deimos no J2,C22,  no  phobos, high gamma!
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d6'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,0e3,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# Out:
# ../phobos_deimos2/d6_ext.txt
# ../phobos_deimos2/d6_pm0.txt
# kk= 1

# %%
numberpm=1  #  with J2,C22,  no  phobos, high gamma!
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d7'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,0e3,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# Out:
# ../phobos_deimos2/d7_ext.txt
# ../phobos_deimos2/d7_pm0.txt
# kk= 1

# %%
numberpm=2  #  Deimos,  no J2,C22,  drifting phobos, high gamma
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d8'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,1e4,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# Out:
# ../phobos_deimos2/d8_ext.txt
# ../phobos_deimos2/d8_pm0.txt
# ../phobos_deimos2/d8_pm1.txt
# kk= 2

# %%
numberpm=2  #  Deimos,   J2,C22,  drifting phobosX10, high gamma
Rmars = 547.0; omega_Mars = 0.11; afac = 2.**(2./3.)  
parmfile='d9'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols_D(fileroot,numberpm,parmfile + '.png',Rmars,afac,3e3,0)  #  savefile, then tmin,tmax
#plt_cols_D(fileroot,numberpm,saveit,Rmars,afac,tmin,tmax):
# Out:
# ../phobos_deimos2/d9_ext.txt
# ../phobos_deimos2/d9_pm0.txt
# ../phobos_deimos2/d9_pm1.txt
# kk= 1

# %%
for ip in range(numberpm-1,-1,-1):
    print(ip)
# Out:
# 1
# 0

# %%
tt,mvec,aaarr,eearr,iiarr,lnarr,ararr,maarr,obliq_deg,spin,Jvec,\
  prec_ang,phi_Eu,theta_Eu,bphi_Eu,dEdtnow,dEdtave,Ivec=orbels_arr(fileroot,numberpm)
plt.plot(tt,eearr[1],'.')
# Out:
# ../phobos_deimos2/d2_ext.txt
# ../phobos_deimos2/d2_pm0.txt
# ../phobos_deimos2/d2_pm1.txt
# kk= 1
